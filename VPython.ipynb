# %%
from vpython import *

# %%
ball = sphere(pos=vec(0,0,0), radius=0.1, make_trail=True,trail_type="points")
t = 0
while t<100:
    rate(10)
    ball.pos = vec(cos(t*0.01), sin(t*0.01), 0)
    t+=1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 100, 101)
y = x**2 +2*x +5

plt.plot(x, y, label='data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
